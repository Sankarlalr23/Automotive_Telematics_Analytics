# %% [markdown]
# <a href="https://colab.research.google.com/github/Sankarlalr23/Automotive_Telematics_Analytics/blob/main/Telematics_Week_2_8_variables_3_clusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Telematics Data Analytics

# %% [markdown]
#     This notebook is for Internship at Xen.AI. The aim is to apply AI/ML on truck data to reduce the downtime/maintenance time by predicting Engine Health Score (EHS).
#     We have to generate an equation and perform time series prediction for the EHS using available data.
#
#     Data Credits  : Dr. Dmitry

# %%
import warnings                         #'do not disturb' mode
warnings.filterwarnings('ignore')

import numpy as np                      # vectors and matrices
import pandas as pd                     # tables and data manipulations
import matplotlib.pyplot as plt         # plots
import seaborn as sns                   # more plots

# %matplotlib inline

# %%
# data = pd.read_csv('telematics_data.csv')   # data importing

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
train_path='/content/drive/My Drive/Xen.AI/'

# %%
data = pd.read_csv('/content/drive/My Drive/Xen.AI/telematics_data.csv')   # data importing

# %%
pd.options.display.max_rows = 200
pd.options.display.max_columns =50     #to show max rows and columns

# %%
data.head()
# Out:
#    year  month  day                vin  wmi engine_cd device_type  \
# 0  2020      4   18  3HSDZTZR9KN352697  3HS        TZ       Xirgo
# 1  2020      5   20  3HSDZTZR9LN055320  3HS        TZ       Xirgo
# 2  2020      4    1  3HSDZTZR0KN354211  3HS        TZ       Xirgo
# 3  2020      5    5  3HSDWTZR8LN845362  3HS        TZ       Xirgo
# 4  2020      4    7  3HSDZTZRXLN085409  3HS        TZ          N2
#
#                 msg_ts                           vin_utc_key  packet_id  \
# 0  2020-04-18 06:50:40  3HSDZTZR9KN3526972020-04-18 06:50:40         36
# 1  2020-05-20 03:01:09  3HSDZTZR9LN0553202020-05-20 03:01:09         36
# 2  2020-04-01 20:02:39  3HSDZTZR0KN3542112020-04-01 20:02:39         36
# 3  2020-05-05 06:17:36  3HSDWTZR8LN8453622020-05-05 06:17:36         36
# 4  2020-04-07 20:14:07  3HSDZTZRXLN0854092020-04-07 20:14:07         36
#
#    reason_code  script_version     deviceid   latitude   longitude  \
# 0            9           204.0    173101817  38.799149  -90.603680
# 1            9           204.0    172301945  33.618963  -84.333847
# 2            9           204.0    173511306  41.139005 -101.173123
# 3            9           204.0    173404340  38.856184  -98.139251
# 4            9           204.0  190815-0009  33.351086  -87.017387
#
#    driveridcode1             obdvin  vehiclebattvolts  fuel_total  engine_rpm  \
# 0            0.0  3HSDZTZR9KN352697              14.2    106165.0      1144.0
# 1            0.0  3HSDZTZR9LN055320               NaN         NaN       584.0
# 2            0.0  3HSDZTZR0KN354211               NaN    113134.0      1145.0
# 3            0.0  3HSDWTZR8LN845362              14.0    149410.0      1368.0
# 4            0.0  3HSDZTZRXLN085409              14.1     33886.0      1167.0
#
#    coolant_tmp  fuel_lvl_pct  driving_tme_sec  cruise_tme_sec  idle_tme_sec  \
# 0         79.0          41.0              NaN             NaN     2167380.0
# 1         61.0           NaN              NaN             NaN           NaN
# 2         81.0           NaN              NaN             NaN     1788120.0
# 3         81.0          54.0              NaN             NaN      786600.0
# 4         82.0           NaN        4755420.0             NaN           NaN
#
#    idle_fuel_total  pto_tme_total  pto_fuel_total  gear  fuel_tmp  oil_tmpl  \
# 0           1503.0            0.0             0.0   1.0       0.0      76.0
# 1              NaN            NaN             0.0   2.0       0.0      56.0
# 2           1172.0            NaN             0.0   1.0       0.0       NaN
# 3            497.0            0.0             0.0   1.0       0.0      86.0
# 4            504.0            0.0             0.0   1.0       NaN      88.0
#
#    throt_pos  mpg  acel_pos  engine_pct_load  torque  oil_lvl  oil_psi  \
# 0        0.0  NaN       0.0             11.0    12.0      0.0    340.0
# 1        1.0  NaN       0.0             26.0    11.0      0.0    228.0
# 2        0.0  NaN       NaN             41.0    42.0      NaN    320.0
# 3        0.0  NaN       0.0             19.0    19.0      0.0    424.0
# 4        0.0  NaN       NaN             65.0    67.0      NaN    320.0
#
#    coolant_psi  intak_air_tmp  manifold_tmp  vehiclespeed  heading  \
# 0          0.0            4.0          10.0        1005.0    960.0
# 1          0.0           24.0           NaN          11.0    700.0
# 2          0.0           25.0           NaN           NaN   2709.0
# 3          0.0           13.0          30.0        1095.0    838.0
# 4          NaN            NaN           NaN        1090.0    458.0
#
#    odometerinmeters  odometer
# 0       380663000.0  380663.0
# 1        88781990.0       NaN
# 2       416436440.0       NaN
# 3       426460520.0       NaN
# 4       107975440.0       NaN

# %%
# data.info()

# %%
# data.describe().T

# %%
# data.isnull().sum()/len(data) * 100   #percentage of missing values

# %%
print('Total rows = {} \n'.format(len(data)))

for i in data.columns:   #lets see value counts in each column, print value & count if unique value < 106 (105 in deviceid)
    
    print('{}'.format(i))
    
    if len(data[i].value_counts())<106:
        print(data[i].value_counts())
        
    else:
        print("{} has More than 106 values".format(i))
        
    print('Number of values =', data[i].nunique())   #Unique values
    print('Percentage of Missing values = %.2f'%(data[i].isnull().sum()/len(data) * 100), '%')  #Missing value percentage
    print('Percentage of Zero = %.2f'%(np.shape(np.where(data[i]==0))[1] / len(data) * 100), '%', '\n') #percetnage of 0
# Out:
# Total rows = 514994
#
# year
# 2020    514994
# Name: year, dtype: int64
# Number of values = 1
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# month
# 4    299339
# 5    215655
# Name: month, dtype: int64
# Number of values = 2
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# day
# 8     30136
# 4     26772
# 5     23166
# 14    22010
# 15    21944
# 1     20784
# 29    20444
# 7     20259
# 13    20209
# 27    19883
# 6     19324
# 20    19160
# 18    18087
# 11    16606
# 23    16270
# 9     16004
# 24    15687
# 19    15648
# 3     15644
# 25    15228
# 2     15182
# 21    14887
# 12    13911
# 30    12962
# 10    12318
# 28    11887
# 26    11585
# 16    10745
# 22    10605
# 17     4596
# 31     3051
# Name: day, dtype: int64
# Number of values = 31
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# vin
# 3HSDZTZR5LN134290    34636
# 1HSERTZRXLH809470     9962
# 3HSDZTZRXLN395656     7263
# 3HSDZTZRXLN085409     6657
# 3HSDZTZR3LN154022     6639
# 3HCDZTZR1LL880100     6583
# 3HCDZTZR9LL880099     6401
# 3HCDZTZR3LL880101     6267
# 3HSDZTZR8KN398425     6048
# 3HSDZTZR1KN174476     5873
# 3HSDZTZR3MN096740     5791
# 3HSDZTZR4LN056083     5586
# 3HCDZTZR6ML684705     5362
# 3HSDZTZR5LN164115     5343
# 3HCDZTZR5LL880102     5316
# 3HCDZTZR7LL880103     5315
# 3HSDZTZR3KN315175     5291
# 3HSDZTZR2LN230944     5289
# 3HSDZTZR0LN880114     5239
# 3HSDZTZR6LN056148     5208
# 3HSDZTZR3LN833708     5132
# 3HSDZTZR4KN126504     5116
# 3HSDZTZR1LN871454     5097
# 3HSDWTZR9LN844849     5074
# 3HSDZTZR6LN065318     5051
# 3HSDZTZR0LN437333     5039
# 3HCDZTZR1ML681274     5030
# 3HSDZTZR2LN075067     4976
# 3HSDZTZR4KN547798     4961
# 3HSDWTZR6LN844811     4957
# 3HCDZTZR0ML681251     4932
# 3HCDZTZRXLL056502     4924
# 3HSDWTZR8LN845362     4916
# 3HSDZTZR7LN630689     4896
# 3HSDWTZR5LN844783     4891
# 3HSDZTZR5KN140444     4878
# 3HSDWTZR7LN064378     4869
# 3HSDZTZR3LN164114     4843
# 3HSDWTZR2LN845423     4830
# 3HSDWTZR1LN845090     4809
# 3HSDWTZR9LN810071     4794
# 3HSDZTZR8KN537162     4773
# 3HSDWTZR1LN887792     4749
# 3HSDWTZRXKN315831     4736
# 3HSDZTZR4LN822992     4710
# 3HSDZTZR1LN081863     4708
# 3HSDWTZR3LN845348     4694
# 3HSDWTZR2LN844773     4681
# 3HSDZTZR0LN384388     4663
# 3HSDZTZR1LN125327     4653
# 3HSDWTZRXLN844861     4614
# 3HSDWTZR2LN845308     4612
# 3HSDZTZR9LN055320     4596
# 3HSDZTZR9LN085496     4568
# 3HSDZTZR9KN136686     4556
# 3HSDZTZR2LN112232     4550
# 3HSDZTZR0KN354211     4539
# 3HSDZTZR3LN852131     4535
# 3HSDZTZR0LN630677     4533
# 3HSDWTZR8LN845216     4532
# 3HCDYTZN8LL296583     4489
# 3HSDZTZR2LN817113     4475
# 3HSDWTZR8LN845149     4466
# 3HSDWTZR6LN854884     4460
# 3HSDWTZRXLN845024     4455
# 3HSDWTZR7LN844803     4434
# 3HSDWTZR5LN845092     4426
# 3HSDZTZR0KN279915     4421
# 3HSDZTZR0LN062656     4417
# 3HSDWTZR9LN845466     4402
# 3HSDWTZR0LN845338     4399
# 3HSDWTZR3LN211277     4393
# 3HSDZTZR8LN139435     4387
# 3HCDZTZR1LL158318     4377
# 3HSDWTZR2LN854882     4361
# 3HCDZTZR6LL833595     4356
# 3HSDWTZR3KN308686     4349
# 3HSDWTZR8KN308697     4345
# 3HSDWTZR9LN845094     4343
# 3HSDZTZRXLN443043     4325
# 3HSDZTZR0LN291791     4324
# 3HSDWTZR5LN845352     4321
# 3HSDZTZR3LN054647     4313
# 3HSDWTZRXKN310631     4313
# 3HSDZTZR4KN227364     4291
# 3HSDZTZR1LN290908     4273
# 3HSDZTZR2LN630681     4260
# 3HCDZTZR6LL833600     4256
# 3HSDZTZR6LN056070     4242
# 3HCDZTZR2LL070362     4233
# 3HSDWTZR7LN810070     4232
# 3HSDZTZR6LN112511     4228
# 3HSDZTZR9KN352697     4211
# 3HSDWTZR9LN845337     4210
# 3HSDZTZR7KN314305     4205
# 3HSDWTZR9KN310622     4204
# 3HSDWTZR5LN845108     4185
# 3HSDWTZR1LN845199     4181
# 3HSDZTZR6KN540223     4177
# 3HSDWTZR0LN844822     4169
# Name: vin, dtype: int64
# Number of values = 100
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# wmi
# 3HS    433191
# 3HC     71841
# 1HS      9962
# Name: wmi, dtype: int64
# Number of values = 3
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# engine_cd
# TZ    514994
# Name: engine_cd, dtype: int64
# Number of values = 1
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# device_type
# Xirgo    414156
# N2       100838
# Name: device_type, dtype: int64
# Number of values = 2
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# msg_ts
# msg_ts has More than 106 values
# Number of values = 472918
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# vin_utc_key
# vin_utc_key has More than 106 values
# Number of values = 503424
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# packet_id
# 36    514994
# Name: packet_id, dtype: int64
# Number of values = 1
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# reason_code
# 9    514994
# Name: reason_code, dtype: int64
# Number of values = 1
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# script_version
# 204.0    368108
# 203.0      9777
# 202.0      9196
# 205.0      2488
# Name: script_version, dtype: int64
# Number of values = 4
# Percentage of Missing values = 24.35 %
# Percentage of Zero = 0.00 %
#
# deviceid
# 173406713      33776
# 173609885       9767
# 190912-0002     6385
# 190912-0010     6208
# 190930-0104     6074
# 200129-0308     5646
# 173101356       5556
# 172304411       5236
# 190925-0048     5181
# 191008-0057     5178
# 190830-0128     5156
# 190930-0120     5153
# 190820-0094     5139
# 173101835       4974
# 191030-0107     4968
# 191019-0067     4883
# 173502918       4875
# 173502526       4869
# 173100734       4819
# 180502617       4786
# 191019-0061     4782
# 172304208       4755
# 190828-0133     4688
# 173101045       4661
# 172106709       4659
# 172303105       4651
# 173403603       4635
# 173103744       4632
# 173407376       4619
# 173511297       4613
# 190720-0099     4594
# 172304180       4579
# 172302416       4571
# 173404340       4558
# 173405767       4538
# 180503386       4508
# 180500129       4499
# 172407237       4490
# 180502953       4466
# 190729-0230     4434
# 172304488       4432
# 190720-0091     4424
# 173511724       4423
# 173102863       4413
# 172301384       4395
# 173406114       4362
# 173511248       4357
# 173101443       4325
# 173511364       4320
# 191115-0040     4313
# 172300794       4310
# 172107479       4305
# 172301945       4281
# 173501805       4280
# 173511306       4266
# 190705-0188     4243
# 173403726       4211
# 180500300       4211
# 191115-0035     4196
# 173405742       4195
# 173511477       4187
# 172501043       4136
# 172409433       4133
# 173502990       4131
# 173101778       4129
# 180500323       4119
# 172407933       4105
# 172201914       4101
# 173103073       4091
# 172303011       4080
# 172300632       4071
# 173404679       4069
# 172106430       4060
# 173511493       4057
# 173103076       4033
# 173502468       4030
# 173104829       4024
# 172302291       4024
# 173103913       4019
# 180502072       4019
# 173407203       4015
# 173502509       4005
# 172502479       4001
# 173503925       4000
# 173103580       3997
# 192608020       3984
# 180501226       3970
# 173404992       3966
# 173101751       3954
# 173101817       3929
# 173511871       3904
# 180501458       3889
# 173103873       3880
# 172200480       3879
# 172302772       3873
# 192606648       3843
# 172500680       3602
# 172300721       3222
# 172201012       3194
# 173104028       3134
# 192607076       3055
# 190815-0009     2865
# 172300092       2795
# 190913-0132     2328
# 172501784       2028
# Name: deviceid, dtype: int64
# Number of values = 105
# Percentage of Missing values = 5.29 %
# Percentage of Zero = 0.00 %
#
# latitude
# latitude has More than 106 values
# Number of values = 440731
# Percentage of Missing values = 5.30 %
# Percentage of Zero = 0.20 %
#
# longitude
# longitude has More than 106 values
# Number of values = 450452
# Percentage of Missing values = 5.29 %
# Percentage of Zero = 0.22 %
#
# driveridcode1
# 0.0    487608
# Name: driveridcode1, dtype: int64
# Number of values = 1
# Percentage of Missing values = 5.32 %
# Percentage of Zero = 94.68 %
#
# obdvin
# 3HSDZTZR5LN134290    33780
# 1HSERTZRXLH809470     9766
# 3HSDZTZRXLN395656     7016
# 3HSDZTZRXLN085409     6449
# 3HCDZTZR1LL880100     6387
# 3HSDZTZR3LN154022     6264
# 3HCDZTZR9LL880099     6210
# 3HCDZTZR3LL880101     6059
# 3HSDZTZR8KN398425     5917
# 3HSDZTZR3MN096740     5646
# 3HSDZTZR1KN174476     5544
# 3HSDZTZR4LN056083     5256
# 3HCDZTZR5LL880102     5182
# 3HCDZTZR7LL880103     5173
# 3HCDZTZR6ML684705     5172
# 3HSDZTZR5LN164115     5171
# 3HSDZTZR2LN230944     5126
# 3HSDZTZR3KN315175     5014
# 3HSDZTZR1LN871454     4975
# 3HSDZTZR6LN056148     4896
# 3HSDZTZR3LN833708     4858
# 3HCDZTZR1ML681274     4843
# 3HSDZTZR4KN126504     4830
# 3HSDZTZR0LN880114     4771
# 3HCDZTZR0ML681251     4763
# 3HSDZTZR6LN065318     4761
# 3HSDWTZR9LN844849     4683
# 3HSDZTZR3LN164114     4669
# 3HSDZTZR2LN075067     4658
# 3HSDZTZR4KN547798     4657
# 3HSDZTZR0LN437333     4654
# 3HCDZTZRXLL056502     4646
# 3HSDZTZR7LN630689     4634
# 3HSDZTZR5KN140444     4620
# 3HSDWTZR6LN844811     4607
# 3HSDWTZR1LN887792     4606
# 3HSDWTZR7LN064378     4572
# 3HSDWTZR8LN845362     4551
# 3HSDWTZR5LN844783     4538
# 3HSDWTZR9LN810071     4514
# 3HSDWTZR2LN845423     4490
# 3HSDWTZR1LN845090     4473
# 3HSDZTZR8KN537162     4449
# 3HSDZTZR9LN085496     4443
# 3HSDZTZR1LN081863     4436
# 3HSDWTZRXKN315831     4415
# 3HSDZTZR4LN822992     4409
# 3HSDZTZR0LN384388     4408
# 3HSDZTZR3LN852131     4399
# 3HSDWTZR2LN844773     4346
# 3HCDYTZN8LL296583     4341
# 3HSDWTZR3LN845348     4340
# 3HSDZTZR9KN136686     4334
# 3HSDZTZR2LN112232     4322
# 3HSDWTZR6LN854884     4309
# 3HSDWTZR2LN845308     4307
# 3HSDZTZR9LN055320     4301
# 3HSDWTZRXLN844861     4294
# 3HSDZTZR1LN125327     4271
# 3HSDZTZR0KN354211     4247
# 3HSDWTZR3LN211277     4240
# 3HSDWTZR8LN845216     4228
# 3HSDZTZR0LN630677     4216
# 3HSDZTZR2LN817113     4207
# 3HSDWTZR2LN854882     4207
# 3HSDZTZR8LN139435     4187
# 3HSDZTZR0LN062656     4153
# 3HSDWTZR7LN844803     4128
# 3HSDZTZR0KN279915     4127
# 3HSDWTZRXLN845024     4121
# 3HSDWTZR8LN845149     4119
# 3HSDZTZR6LN056070     4096
# 3HSDWTZR9LN845466     4091
# 3HSDWTZR5LN845092     4086
# 3HSDZTZR4KN227364     4084
# 3HSDZTZR0LN291791     4078
# 3HCDZTZR1LL158318     4075
# 3HSDZTZRXLN443043     4064
# 3HSDWTZR0LN845338     4061
# 3HCDZTZR6LL833595     4038
# 3HSDWTZR8KN308697     4038
# 3HSDWTZR9LN845094     4024
# 3HCDZTZR2LL070362     4023
# 3HSDZTZR1LN290908     4012
# 3HSDWTZRXKN310631     4002
# 3HSDZTZR6LN112511     3999
# 3HSDWTZR5LN845352     3997
# 3HSDZTZR3LN054647     3992
# 3HSDZTZR2LN630681     3992
# 3HSDWTZR7LN810070     3977
# 3HSDZTZR7KN314305     3977
# 3HSDWTZR3KN308686     3974
# 3HCDZTZR6LL833600     3974
# 3HSDZTZR6KN540223     3967
# 3HSDZTZR9KN352697     3950
# 3HSDWTZR1LN845199     3901
# 3HSDWTZR9LN845337     3899
# 3HSDWTZR9KN310622     3893
# 3HSDWTZR0LN844822     3864
# 3HSDWTZR5LN845108     3856
# Name: obdvin, dtype: int64
# Number of values = 100
# Percentage of Missing values = 5.30 %
# Percentage of Zero = 0.00 %
#
# vehiclebattvolts
# 14.10    138277
# 14.00    100141
# 14.20     76251
# 13.90     47612
# 13.80     28677
# 14.30     12883
# 13.70     12407
# 13.85     11797
# 14.05      8718
# 13.95      6701
# 13.75      6289
# 13.60      2924
# 13.65      1341
# 13.50       971
# 14.40       817
# 13.40       578
# 14.15       371
# 13.30       301
# 13.55       234
# 13.20       218
# 13.10       117
# 13.00        65
# 12.90        42
# 13.45        25
# 12.80        25
# 12.70        23
# 12.60        11
# 12.40         6
# 12.50         5
# 12.85         4
# 13.15         4
# 12.20         3
# 14.50         3
# 12.35         2
# 12.65         2
# 12.95         2
# 13.35         2
# 11.60         1
# 12.30         1
# 12.10         1
# 11.80         1
# 14.80         1
# 14.60         1
# 13.25         1
# Name: vehiclebattvolts, dtype: int64
# Number of values = 44
# Percentage of Missing values = 11.09 %
# Percentage of Zero = 0.00 %
#
# fuel_total
# fuel_total has More than 106 values
# Number of values = 153159
# Percentage of Missing values = 11.81 %
# Percentage of Zero = 0.00 %
#
# engine_rpm
# engine_rpm has More than 106 values
# Number of values = 1529
# Percentage of Missing values = 0.00 %
# Percentage of Zero = 0.00 %
#
# coolant_tmp
# coolant_tmp has More than 106 values
# Number of values = 108
# Percentage of Missing values = 11.10 %
# Percentage of Zero = 0.00 %
#
# fuel_lvl_pct
# 100.0    51886
# 99.0     23172
# 66.0     15157
# 74.0     13080
# 92.0     10477
# 34.0      9252
# 72.0      8726
# 68.0      7735
# 60.0      6998
# 79.0      6900
# 47.0      6549
# 80.0      6346
# 54.0      6247
# 86.0      6093
# 53.0      5931
# 48.0      5555
# 93.0      5292
# 59.0      5208
# 40.0      5042
# 41.0      4108
# 62.0      3994
# 28.0      3912
# 76.0      3841
# 87.0      3786
# 64.0      3728
# 90.0      3686
# 70.0      3582
# 85.0      2922
# 44.0      2147
# 78.0      1929
# 88.0      1851
# 26.0      1666
# 46.0      1569
# 98.0      1558
# 21.0      1555
# 22.0      1113
# 81.0      1093
# 77.0      1024
# 52.0      1009
# 84.0       993
# 97.0       986
# 58.0       875
# 83.0       873
# 82.0       852
# 94.0       845
# 15.0       826
# 96.0       816
# 55.0       792
# 89.0       739
# 95.0       690
# 36.0       664
# 57.0       662
# 39.0       639
# 49.0       622
# 56.0       591
# 50.0       550
# 51.0       533
# 29.0       458
# 42.0       453
# 20.0       448
# 32.0       401
# 14.0       378
# 38.0       359
# 37.0       329
# 31.0       257
# 30.0       207
# 25.0       190
# 23.0       162
# 16.0       162
# 24.0       147
# 8.0        100
# 10.0        70
# 17.0        69
# 7.0         68
# 18.0        53
# 45.0        31
# 61.0        31
# 43.0        24
# 12.0        23
# 11.0        23
# 33.0        17
# 35.0        17
# 4.0         11
# 27.0        11
# 91.0         8
# 2.0          7
# 75.0         7
# 71.0         6
# 69.0         6
# 19.0         5
# 6.0          5
# 63.0         3
# 73.0         2
# 5.0          2
# 13.0         2
# 67.0         1
# 65.0         1
# Name: fuel_lvl_pct, dtype: int64
# Number of values = 97
# Percentage of Missing values = 46.83 %
# Percentage of Zero = 0.00 %
#
# driving_tme_sec
# driving_tme_sec has More than 106 values
# Number of values = 49290
# Percentage of Missing values = 81.86 %
# Percentage of Zero = 0.00 %
#
# cruise_tme_sec
# Series([], Name: cruise_tme_sec, dtype: int64)
# Number of values = 0
# Percentage of Missing values = 100.00 %
# Percentage of Zero = 0.00 %
#
# idle_tme_sec
# idle_tme_sec has More than 106 values
# Number of values = 23621
# Percentage of Missing values = 11.88 %
# Percentage of Zero = 0.00 %
#
# idle_fuel_total
# idle_fuel_total has More than 106 values
# Number of values = 4148
# Percentage of Missing values = 11.92 %
# Percentage of Zero = 0.00 %
#
# pto_tme_total
# pto_tme_total has More than 106 values
# Number of values = 601
# Percentage of Missing values = 11.90 %
# Percentage of Zero = 81.65 %
#
# pto_fuel_total
# pto_fuel_total has More than 106 values
# Number of values = 461
# Percentage of Missing values = 11.92 %
# Percentage of Zero = 82.38 %
#
# gear
# 1.0    401218
# 3.0     31642
# 2.0      2523
# 0.0      2311
# Name: gear, dtype: int64
# Number of values = 4
# Percentage of Missing values = 15.01 %
# Percentage of Zero = 0.45 %
#
# fuel_tmp
#  0.0     364034
# -40.0       388
# Name: fuel_tmp, dtype: int64
# Number of values = 2
# Percentage of Missing values = 29.24 %
# Percentage of Zero = 70.69 %
#
# oil_tmpl
# oil_tmpl has More than 106 values
# Number of values = 121
# Percentage of Missing values = 11.08 %
# Percentage of Zero = 0.00 %
#
# throt_pos
# 0.0      244172
# 100.0     92048
# 58.0       2036
# 56.0       2011
# 64.0       1976
# 52.0       1974
# 62.0       1963
# 60.0       1963
# 54.0       1904
# 68.0       1849
# 66.0       1846
# 50.0       1793
# 48.0       1720
# 46.0       1697
# 98.0       1651
# 70.0       1637
# 99.0       1637
# 76.0       1634
# 44.0       1594
# 78.0       1583
# 72.0       1571
# 74.0       1570
# 42.0       1562
# 84.0       1554
# 80.0       1527
# 82.0       1507
# 96.0       1482
# 40.0       1453
# 94.0       1438
# 92.0       1423
# 32.0       1414
# 90.0       1402
# 86.0       1399
# 22.0       1390
# 38.0       1388
# 18.0       1373
# 16.0       1367
# 34.0       1359
# 88.0       1353
# 24.0       1347
# 36.0       1340
# 59.0       1329
# 20.0       1324
# 61.0       1316
# 28.0       1307
# 26.0       1306
# 53.0       1305
# 30.0       1294
# 63.0       1283
# 69.0       1277
# 67.0       1276
# 57.0       1276
# 65.0       1242
# 55.0       1224
# 14.0       1209
# 51.0       1199
# 75.0       1140
# 47.0       1134
# 45.0       1113
# 71.0       1111
# 43.0       1095
# 49.0       1095
# 73.0       1094
# 97.0       1054
# 77.0       1048
# 12.0       1020
# 2.0         999
# 41.0        987
# 39.0        983
# 83.0        981
# 81.0        955
# 79.0        954
# 35.0        949
# 21.0        946
# 95.0        941
# 37.0        932
# 31.0        924
# 87.0        923
# 27.0        917
# 91.0        904
# 85.0        902
# 25.0        900
# 93.0        891
# 33.0        887
# 19.0        886
# 29.0        870
# 17.0        855
# 89.0        850
# 23.0        840
# 15.0        834
# 4.0         823
# 10.0        813
# 8.0         792
# 13.0        774
# 6.0         693
# 11.0        647
# 9.0         594
# 3.0         592
# 5.0         457
# 7.0         456
# 1.0         344
# Name: throt_pos, dtype: int64
# Number of values = 101
# Percentage of Missing values = 11.07 %
# Percentage of Zero = 47.41 %
#
# mpg
# Series([], Name: mpg, dtype: int64)
# Number of values = 0
# Percentage of Missing values = 100.00 %
# Percentage of Zero = 0.00 %
#
# acel_pos
# 0.0     363205
# 96.0       957
# 46.0       103
# 1.0         99
# 14.0        29
# 97.0        12
# 42.0         9
# 40.0         8
# 38.0         6
# 33.0         4
# Name: acel_pos, dtype: int64
# Number of values = 10
# Percentage of Missing values = 29.24 %
# Percentage of Zero = 70.53 %
#
# engine_pct_load
# engine_pct_load has More than 106 values
# Number of values = 128
# Percentage of Missing values = 7.59 %
# Percentage of Zero = 9.94 %
#
# torque
# torque has More than 106 values
# Number of values = 114
# Percentage of Missing values = 7.70 %
# Percentage of Zero = 9.98 %
#
# oil_lvl
# 0.0    364709
# Name: oil_lvl, dtype: int64
# Number of values = 1
# Percentage of Missing values = 29.18 %
# Percentage of Zero = 70.82 %
#
# oil_psi
# oil_psi has More than 106 values
# Number of values = 231
# Percentage of Missing values = 11.08 %
# Percentage of Zero = 0.01 %
#
# coolant_psi
# 0.0    364519
# Name: coolant_psi, dtype: int64
# Number of values = 1
# Percentage of Missing values = 29.22 %
# Percentage of Zero = 70.78 %
#
# intak_air_tmp
#  19.0    20963
#  21.0    20667
#  22.0    20582
#  23.0    20340
#  20.0    20113
#  18.0    19764
#  24.0    19235
#  17.0    18950
#  16.0    17748
#  15.0    17101
#  14.0    16550
#  13.0    15402
#  26.0    15008
#  25.0    14776
#  27.0    14097
#  12.0    14034
#  11.0    13048
#  28.0    12866
#  10.0    11951
#  29.0    10856
#  30.0    10850
#  9.0     10643
#  31.0    10214
#  8.0      8899
#  32.0     8462
#  33.0     8071
#  7.0      7388
#  34.0     7015
#  6.0      5996
#  35.0     5689
#  5.0      4749
#  36.0     4498
#  37.0     4146
#  4.0      3782
#  38.0     3321
#  3.0      3040
#  39.0     2414
#  2.0      2015
#  0.0      1749
#  40.0     1736
#  1.0      1559
#  41.0     1415
#  42.0     1093
#  43.0      825
#  44.0      592
# -2.0       566
#  45.0      508
# -3.0       396
#  46.0      354
# -4.0       307
# -5.0       261
#  47.0      249
# -6.0       216
# -1.0       171
#  48.0      151
# -7.0       142
#  49.0      115
# -8.0        89
# -9.0        77
#  50.0       65
# -10.0       53
#  51.0       52
#  52.0       44
# -11.0       34
#  55.0       27
#  54.0       24
# -13.0       21
# -12.0       19
#  53.0       18
# -14.0       14
#  56.0       13
# -15.0       12
#  57.0       12
# -16.0       10
#  58.0        7
#  61.0        5
#  59.0        3
# -18.0        3
# -17.0        3
# -19.0        3
# -20.0        2
#  60.0        2
#  63.0        2
#  64.0        1
# -21.0        1
#  66.0        1
#  62.0        1
#  65.0        1
# Name: intak_air_tmp, dtype: int64
# Number of values = 88
# Percentage of Missing values = 11.02 %
# Percentage of Zero = 0.34 %
#
# manifold_tmp
#  38.0    19878
#  37.0    19841
#  40.0    19825
#  36.0    19392
#  39.0    19216
#  41.0    18775
#  35.0    18709
#  34.0    17996
#  42.0    17873
#  33.0    16779
#  43.0    16347
#  32.0    15502
#  44.0    15232
#  45.0    14133
#  31.0    14063
#  30.0    12688
#  46.0    12676
#  47.0    11666
#  48.0    10684
#  29.0    10484
#  49.0     9557
#  28.0     9264
#  50.0     8528
#  27.0     8356
#  26.0     7404
#  51.0     7197
#  25.0     6522
#  52.0     6208
#  24.0     5750
#  53.0     5485
#  23.0     5204
#  54.0     4734
#  22.0     4560
#  55.0     4292
#  21.0     3886
#  56.0     3578
#  20.0     3359
#  57.0     3137
#  58.0     2728
#  59.0     2297
#  19.0     2213
#  18.0     2053
#  17.0     1758
#  60.0     1726
#  16.0     1696
#  61.0     1418
#  15.0     1418
#  62.0     1187
#  14.0     1182
#  63.0     1099
#  13.0     1003
#  64.0      875
#  65.0      828
#  12.0      790
#  66.0      763
#  11.0      714
#  10.0      580
#  67.0      452
#  9.0       440
#  68.0      407
#  8.0       348
#  69.0      342
#  70.0      253
#  7.0       247
#  6.0       225
#  5.0       171
#  71.0      147
#  4.0       136
#  3.0       109
#  72.0       79
#  2.0        66
#  1.0        51
#  0.0        48
#  73.0       48
#  74.0       25
#  75.0       23
#  76.0       14
# -2.0        11
# -3.0        10
#  77.0        9
#  78.0        7
# -5.0         6
# -7.0         5
# -1.0         4
# -4.0         3
#  81.0        3
# -6.0         3
#  79.0        2
#  80.0        2
# -9.0         2
#  84.0        2
#  82.0        1
# -8.0         1
# -11.0        1
# Name: manifold_tmp, dtype: int64
# Number of values = 94
# Percentage of Missing values = 10.91 %
# Percentage of Zero = 0.01 %
#
# vehiclespeed
# vehiclespeed has More than 106 values
# Number of values = 1332
# Percentage of Missing values = 5.31 %
# Percentage of Zero = 7.54 %
#
# heading
# heading has More than 106 values
# Number of values = 3599
# Percentage of Missing values = 8.13 %
# Percentage of Zero = 0.00 %
#
# odometerinmeters
# odometerinmeters has More than 106 values
# Number of values = 445613
# Percentage of Missing values = 5.28 %
# Percentage of Zero = 0.03 %
#
# odometer
# odometer has More than 106 values
# Number of values = 9400
# Percentage of Missing values = 97.98 %
# Percentage of Zero = 0.05 %

# %%
# data.columns

# %%
# Data frame with important variables only
 
# df = pd.DataFrame(data, columns = ['msg_ts','vin','device_type','deviceid','fuel_total','engine_rpm','coolant_tmp',
#                                 'oil_tmpl','throt_pos','torque','oil_psi','manifold_tmp','vehiclespeed','odometerinmeters'])
 
 
# lets not use device type and device id and vehiclespeed
df = pd.DataFrame(data, columns = ['vin','msg_ts','device_type','fuel_total','engine_rpm','coolant_tmp','oil_tmpl',
                       'throt_pos','torque','oil_psi','manifold_tmp','odometerinmeters'])

# %%
df
# Out:
#                       vin               msg_ts device_type  fuel_total  \
# 0       3HSDZTZR9KN352697  2020-04-18 06:50:40       Xirgo    106165.0
# 1       3HSDZTZR9LN055320  2020-05-20 03:01:09       Xirgo         NaN
# 2       3HSDZTZR0KN354211  2020-04-01 20:02:39       Xirgo    113134.0
# 3       3HSDWTZR8LN845362  2020-05-05 06:17:36       Xirgo    149410.0
# 4       3HSDZTZRXLN085409  2020-04-07 20:14:07          N2     33886.0
# ...                   ...                  ...         ...         ...
# 514989  3HSDZTZR1LN125327  2020-04-29 12:06:30       Xirgo     95643.0
# 514990  3HSDZTZR6LN065318  2020-05-11 15:30:59       Xirgo     83040.0
# 514991  3HSDWTZR5LN845352  2020-05-09 11:12:30       Xirgo    140542.0
# 514992  3HSDZTZR5LN134290  2020-04-16 04:27:08       Xirgo     86642.0
# 514993  3HSDZTZR4KN547798  2020-04-18 13:15:09       Xirgo     92497.0
#
#         engine_rpm  coolant_tmp  oil_tmpl  throt_pos  torque  oil_psi  \
# 0           1144.0         79.0      76.0        0.0    12.0    340.0
# 1            584.0         61.0      56.0        1.0    11.0    228.0
# 2           1145.0         81.0       NaN        0.0    42.0    320.0
# 3           1368.0         81.0      86.0        0.0    19.0    424.0
# 4           1167.0         82.0      88.0        0.0    67.0    320.0
# ...            ...          ...       ...        ...     ...      ...
# 514989      1165.0          NaN      86.0      100.0    59.0    288.0
# 514990       601.0          NaN      80.0        0.0    10.0    148.0
# 514991      1369.0         84.0      92.0        0.0    86.0    328.0
# 514992      1000.0         95.0     101.0        0.0    11.0    248.0
# 514993      1146.0         80.0      80.0        0.0    38.0    328.0
#
#         manifold_tmp  odometerinmeters
# 0               10.0       380663000.0
# 1                NaN        88781990.0
# 2                NaN       416436440.0
# 3               30.0       426460520.0
# 4                NaN       107975440.0
# ...              ...               ...
# 514989          35.0       278538120.0
# 514990          67.0       295970500.0
# 514991           NaN       417229440.0
# 514992           NaN       274880000.0
# 514993          24.0       333465420.0
#
# [514994 rows x 12 columns]

# %%
df.describe().T
# Out:
#                      count          mean           std    min          25%  \
# fuel_total        454170.0  7.267131e+04  4.471582e+04    1.0      40812.0
# engine_rpm        514994.0  1.162784e+03  2.508765e+02  458.0       1098.0
# coolant_tmp       457846.0  8.055149e+01  7.013731e+00  -40.0         80.0
# oil_tmpl          457956.0  8.614560e+01  9.936019e+00 -273.0         85.0
# throt_pos         457973.0  3.441681e+01  4.220618e+01    0.0          0.0
# torque            475351.0  4.264863e+01  3.296667e+01 -125.0          8.0
# oil_psi           457907.0  3.263757e+02  8.667653e+01    0.0        292.0
# manifold_tmp      458811.0  3.829099e+01  1.009876e+01  -11.0         32.0
# odometerinmeters  487801.0  2.300427e+08  1.348677e+08    0.0  129819230.0
#
#                           50%          75%          max
# fuel_total            68874.0      94454.0     257814.0
# engine_rpm             1198.0       1326.0       8191.0
# coolant_tmp              81.0         83.0        103.0
# oil_tmpl                 88.0         90.0        114.0
# throt_pos                 0.0         81.0        100.0
# torque                   42.0         67.0        104.0
# oil_psi                 332.0        372.0        920.0
# manifold_tmp             38.0         45.0         84.0
# odometerinmeters  226549935.0  301607180.0  611547720.0

# %%
df['msg_ts']=pd.to_datetime(df['msg_ts'])  # Converting msg_ts to date time

# %%
df = df.sort_values(['vin','msg_ts'])

# %%
df
# Out:
#                       vin              msg_ts device_type  fuel_total  \
# 159159  1HSERTZRXLH809470 2020-04-01 00:34:45       Xirgo         NaN
# 305957  1HSERTZRXLH809470 2020-04-01 00:45:44       Xirgo      8821.0
# 85501   1HSERTZRXLH809470 2020-04-01 00:46:17       Xirgo      8821.0
# 166563  1HSERTZRXLH809470 2020-04-01 00:48:17       Xirgo      8822.0
# 114931  1HSERTZRXLH809470 2020-04-01 00:48:21       Xirgo      8822.0
# ...                   ...                 ...         ...         ...
# 144123  3HSDZTZRXLN443043 2020-05-30 23:07:32       Xirgo         NaN
# 62736   3HSDZTZRXLN443043 2020-05-30 23:12:32       Xirgo     73207.0
# 324654  3HSDZTZRXLN443043 2020-05-30 23:22:55       Xirgo         NaN
# 414388  3HSDZTZRXLN443043 2020-05-31 22:58:36       Xirgo     73208.0
# 150524  3HSDZTZRXLN443043 2020-05-31 23:11:52       Xirgo         NaN
#
#         engine_rpm  coolant_tmp  oil_tmpl  throt_pos  torque  oil_psi  \
# 159159       649.0         72.0      75.0        NaN     NaN    184.0
# 305957       649.0         71.0      73.0        0.0     5.0    188.0
# 85501        649.0          NaN      73.0        0.0     NaN      NaN
# 166563      1084.0         74.0      74.0        8.0     NaN    400.0
# 114931       751.0         74.0      74.0       10.0     6.0      NaN
# ...            ...          ...       ...        ...     ...      ...
# 144123      1078.0         81.0      93.0        NaN     NaN    300.0
# 62736       1758.0         88.0      97.0        0.0     0.0    532.0
# 324654      1051.0         86.0      93.0       38.0    12.0    380.0
# 414388       588.0         21.0      21.0        0.0     NaN      NaN
# 150524       601.0         48.0      41.0        NaN     5.0    296.0
#
#         manifold_tmp  odometerinmeters
# 159159          32.0        21344555.0
# 305957           NaN        21344615.0
# 85501            NaN        21344615.0
# 166563          31.0               NaN
# 114931          31.0        21344865.0
# ...              ...               ...
# 144123          44.0       250518380.0
# 62736           57.0               NaN
# 324654          59.0       250522360.0
# 414388          20.0       250522720.0
# 150524          29.0       250523260.0
#
# [514994 rows x 12 columns]

# %%
df = df.reset_index()
df = df.drop('index', axis =1)

# %%
df.isnull().sum()/len(df) * 100
# Out:
# vin                  0.000000
# msg_ts               0.000000
# device_type          0.000000
# fuel_total          11.810623
# engine_rpm           0.000000
# coolant_tmp         11.096828
# oil_tmpl            11.075469
# throt_pos           11.072168
# torque               7.697760
# oil_psi             11.084984
# manifold_tmp        10.909447
# odometerinmeters     5.280256
# dtype: float64

# %%
df = df.dropna(axis = 0, how = 'any')

# %%
df
# Out:
#                       vin              msg_ts device_type  fuel_total  \
# 8       1HSERTZRXLH809470 2020-04-01 01:11:49       Xirgo      8822.0
# 14      1HSERTZRXLH809470 2020-04-01 01:19:04       Xirgo      8823.0
# 16      1HSERTZRXLH809470 2020-04-01 01:21:23       Xirgo      8823.0
# 24      1HSERTZRXLH809470 2020-04-01 01:36:23       Xirgo      8830.0
# 29      1HSERTZRXLH809470 2020-04-01 02:11:55       Xirgo      8831.0
# ...                   ...                 ...         ...         ...
# 514973  3HSDZTZRXLN443043 2020-05-30 20:52:10       Xirgo     73155.0
# 514974  3HSDZTZRXLN443043 2020-05-30 21:12:52       Xirgo     73156.0
# 514984  3HSDZTZRXLN443043 2020-05-30 22:32:32       Xirgo     73190.0
# 514985  3HSDZTZRXLN443043 2020-05-30 22:37:32       Xirgo     73192.0
# 514987  3HSDZTZRXLN443043 2020-05-30 22:47:32       Xirgo     73198.0
#
#         engine_rpm  coolant_tmp  oil_tmpl  throt_pos  torque  oil_psi  \
# 8            650.0         73.0      75.0        0.0     5.0    184.0
# 14          1153.0         79.0      78.0        0.0     0.0    416.0
# 16          1107.0         81.0      82.0       30.0    24.0    368.0
# 24          1202.0         81.0      92.0        0.0     0.0    372.0
# 29          1155.0         81.0      81.0       96.0    98.0    468.0
# ...            ...          ...       ...        ...     ...      ...
# 514973       599.0         78.0      82.0        0.0     9.0    148.0
# 514974       600.0         79.0      86.0        0.0     6.0    144.0
# 514984      1278.0         79.0      89.0       69.0    62.0    380.0
# 514985      1078.0         81.0      93.0       92.0    90.0    288.0
# 514987      1261.0         83.0      93.0       83.0    91.0    352.0
#
#         manifold_tmp  odometerinmeters
# 8               31.0        21345125.0
# 14              30.0        21345530.0
# 16              28.0        21347170.0
# 24              32.0        21367125.0
# 29              40.0        21369085.0
# ...              ...               ...
# 514973          61.0       250353980.0
# 514974          52.0       250354380.0
# 514984          35.0       250466060.0
# 514985          41.0       250471320.0
# 514987          47.0       250487140.0
#
# [330352 rows x 12 columns]

# %%
df_xirgo = df[df["device_type"] == 'Xirgo']

# %%
df_xirgo = df_xirgo[df_xirgo["engine_rpm"] >= 1000]

# %%
df_xirgo['device_type'].value_counts()
# Out:
# Xirgo    217876
# Name: device_type, dtype: int64

# %%
df_xirgo = df_xirgo.drop('device_type', axis =1)

# %%
df_xirgo = df_xirgo.reset_index()
df_xirgo = df_xirgo.drop('index', axis =1)

# %%
df_xirgo
# Out:
#                       vin              msg_ts  fuel_total  engine_rpm  \
# 0       1HSERTZRXLH809470 2020-04-01 01:19:04      8823.0      1153.0
# 1       1HSERTZRXLH809470 2020-04-01 01:21:23      8823.0      1107.0
# 2       1HSERTZRXLH809470 2020-04-01 01:36:23      8830.0      1202.0
# 3       1HSERTZRXLH809470 2020-04-01 02:11:55      8831.0      1155.0
# 4       1HSERTZRXLH809470 2020-04-01 02:16:09      8833.0      1487.0
# ...                   ...                 ...         ...         ...
# 217871  3HSDZTZRXLN443043 2020-05-30 20:16:04     73150.0      1152.0
# 217872  3HSDZTZRXLN443043 2020-05-30 20:34:29     73155.0      1085.0
# 217873  3HSDZTZRXLN443043 2020-05-30 22:32:32     73190.0      1278.0
# 217874  3HSDZTZRXLN443043 2020-05-30 22:37:32     73192.0      1078.0
# 217875  3HSDZTZRXLN443043 2020-05-30 22:47:32     73198.0      1261.0
#
#         coolant_tmp  oil_tmpl  throt_pos  torque  oil_psi  manifold_tmp  \
# 0              79.0      78.0        0.0     0.0    416.0          30.0
# 1              81.0      82.0       30.0    24.0    368.0          28.0
# 2              81.0      92.0        0.0     0.0    372.0          32.0
# 3              81.0      81.0       96.0    98.0    468.0          40.0
# 4              83.0      89.0       62.0    46.0    436.0          42.0
# ...             ...       ...        ...     ...      ...           ...
# 217871         81.0      89.0       15.0     6.0    356.0          42.0
# 217872         82.0      91.0       18.0    12.0    328.0          51.0
# 217873         79.0      89.0       69.0    62.0    380.0          35.0
# 217874         81.0      93.0       92.0    90.0    288.0          41.0
# 217875         83.0      93.0       83.0    91.0    352.0          47.0
#
#         odometerinmeters
# 0             21345530.0
# 1             21347170.0
# 2             21367125.0
# 3             21369085.0
# 4             21374645.0
# ...                  ...
# 217871       250336560.0
# 217872       250353460.0
# 217873       250466060.0
# 217874       250471320.0
# 217875       250487140.0
#
# [217876 rows x 11 columns]

# %%
df_xirgo.isnull().sum()/len(df) * 100
# Out:
# vin                 0.0
# msg_ts              0.0
# fuel_total          0.0
# engine_rpm          0.0
# coolant_tmp         0.0
# oil_tmpl            0.0
# throt_pos           0.0
# torque              0.0
# oil_psi             0.0
# manifold_tmp        0.0
# odometerinmeters    0.0
# dtype: float64

# %%
# Distribution of important features - plot

for i in ['fuel_total']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %% [markdown]
# Right skewed plot

# %%
for i in ['engine_rpm']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %% [markdown]
# Right skewed plot

# %%
for i in ['coolant_tmp']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %% [markdown]
# Left skewed plot

# %%
for i in ['oil_tmpl']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %% [markdown]
# Left skewed plot

# %%
for i in ['throt_pos']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %%
for i in ['torque']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %%
for i in ['oil_psi']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %%
for i in ['manifold_tmp']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %%
#for i in ['vehiclespeed']:
    
 #   g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
  #  g = (g.map(sns.distplot, i , hist=False, rug=True))
 #   plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-abe302ed1e33> in <module>()
#       1 for i in ['vehiclespeed']:
#       2
# ----> 3     g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
#       4     g = (g.map(sns.distplot, i , hist=False, rug=True))
#       5     plt.show()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['vehiclespeed'] not in index"

# %% [markdown]
# Left skewed plot

# %%
for i in ['odometerinmeters']:
    
    g = sns.FacetGrid(df_xirgo[['vin',i]], hue="vin", height = 6, aspect = 1.5)
    g = (g.map(sns.distplot, i , hist=False, rug=True))
    plt.show()

# %% [markdown]
# Right skewed plot

# %%
corrmat = df_xirgo.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat,vmax=1, square=True, annot = True)
plt.show()

# %%
corrmat
# Out:
#                   fuel_total  engine_rpm  coolant_tmp  oil_tmpl  throt_pos  \
# fuel_total          1.000000    0.059670     0.123498  0.089905   0.008614
# engine_rpm          0.059670    1.000000     0.152682  0.098641   0.202554
# coolant_tmp         0.123498    0.152682     1.000000  0.830816   0.120997
# oil_tmpl            0.089905    0.098641     0.830816  1.000000   0.075602
# throt_pos           0.008614    0.202554     0.120997  0.075602   1.000000
# torque              0.075824    0.022497     0.239856  0.139682   0.301529
# oil_psi             0.045921    0.514527    -0.423250 -0.451546   0.139009
# manifold_tmp        0.124930    0.124646     0.441562  0.479355   0.109190
# odometerinmeters    0.945829   -0.008833     0.097291  0.079090  -0.018534
#
#                     torque   oil_psi  manifold_tmp  odometerinmeters
# fuel_total        0.075824  0.045921      0.124930          0.945829
# engine_rpm        0.022497  0.514527      0.124646         -0.008833
# coolant_tmp       0.239856 -0.423250      0.441562          0.097291
# oil_tmpl          0.139682 -0.451546      0.479355          0.079090
# throt_pos         0.301529  0.139009      0.109190         -0.018534
# torque            1.000000 -0.187467      0.248469          0.047415
# oil_psi          -0.187467  1.000000     -0.091275         -0.010098
# manifold_tmp      0.248469 -0.091275      1.000000          0.118855
# odometerinmeters  0.047415 -0.010098      0.118855          1.000000

# %% [markdown]
# There is correlation between variables. To remove these correlation we need to do PCA.

# %% [markdown]
# # Dimensionality Reduction using PCA on multivariate timeseries data
#
# https://medium.com/@ansjin/dimensionality-reduction-using-pca-on-multivariate-timeseries-data-b5cc07238dc4

# %%
from sklearn.preprocessing import StandardScaler # for standardizing the Data
from sklearn.decomposition import PCA # for PCA calculation

# %%
df_xirgo = df_xirgo.sort_values('msg_ts')
df_pca = df_xirgo
df_pca = df_pca.set_index(['msg_ts'])
df_pca
# Out:
#                                    vin  fuel_total  engine_rpm  coolant_tmp  \
# msg_ts
# 2020-04-01 00:00:19  3HSDZTZR5LN134290     83536.0      1489.0         84.0
# 2020-04-01 00:01:06  3HSDWTZR5LN844783     19870.0      1376.0         81.0
# 2020-04-01 00:02:15  3HSDZTZR3LN054647      2818.0      1138.0         81.0
# 2020-04-01 00:02:21  3HSDZTZR5LN134290     83536.0      1462.0         82.0
# 2020-04-01 00:02:44  3HSDZTZR1LN125327     82402.0      1160.0         82.0
# ...                                ...         ...         ...          ...
# 2020-05-31 18:31:11  3HSDWTZR9LN810071     61931.0      1001.0         82.0
# 2020-05-31 18:41:46  3HSDZTZR0LN384388     53670.0      1008.0         82.0
# 2020-05-31 18:44:05  3HSDZTZR1LN290908     75020.0      1183.0         80.0
# 2020-05-31 20:02:05  3HSDZTZR0LN384388     53694.0      1121.0         90.0
# 2020-05-31 21:11:51  3HSDZTZR0LN384388     53701.0      1085.0         81.0
#
#                      oil_tmpl  throt_pos  torque  oil_psi  manifold_tmp  \
# msg_ts
# 2020-04-01 00:00:19      94.0        0.0     0.0    452.0          43.0
# 2020-04-01 00:01:06      83.0      100.0    16.0    388.0          32.0
# 2020-04-01 00:02:15      91.0        0.0     0.0    320.0          35.0
# 2020-04-01 00:02:21      91.0        0.0     0.0    380.0          39.0
# 2020-04-01 00:02:44      86.0        0.0    31.0    312.0          37.0
# ...                       ...        ...     ...      ...           ...
# 2020-05-31 18:31:11      86.0       37.0    33.0    280.0          37.0
# 2020-05-31 18:41:46      87.0        0.0    71.0    264.0          33.0
# 2020-05-31 18:44:05      85.0        0.0    62.0    316.0          38.0
# 2020-05-31 20:02:05      92.0       18.0     8.0    320.0          62.0
# 2020-05-31 21:11:51      89.0       48.0    38.0    292.0          41.0
#
#                      odometerinmeters
# msg_ts
# 2020-04-01 00:00:19       265633380.0
# 2020-04-01 00:01:06       284931580.0
# 2020-04-01 00:02:15        10278765.0
# 2020-04-01 00:02:21       265636940.0
# 2020-04-01 00:02:44       240438540.0
# ...                               ...
# 2020-05-31 18:31:11       196080560.0
# 2020-05-31 18:41:46       186153820.0
# 2020-05-31 18:44:05       265525380.0
# 2020-05-31 20:02:05       186249040.0
# 2020-05-31 21:11:51       186262080.0
#
# [217876 rows x 10 columns]

# %%
# list(df_xirgo['vin'].iloc[:1000])

# %%
df_pca = df_pca.drop(columns = ['vin'], axis=1)
df_pca
# Out:
#                      fuel_total  engine_rpm  coolant_tmp  oil_tmpl  throt_pos  \
# msg_ts
# 2020-04-01 00:00:19     83536.0      1489.0         84.0      94.0        0.0
# 2020-04-01 00:01:06     19870.0      1376.0         81.0      83.0      100.0
# 2020-04-01 00:02:15      2818.0      1138.0         81.0      91.0        0.0
# 2020-04-01 00:02:21     83536.0      1462.0         82.0      91.0        0.0
# 2020-04-01 00:02:44     82402.0      1160.0         82.0      86.0        0.0
# ...                         ...         ...          ...       ...        ...
# 2020-05-31 18:31:11     61931.0      1001.0         82.0      86.0       37.0
# 2020-05-31 18:41:46     53670.0      1008.0         82.0      87.0        0.0
# 2020-05-31 18:44:05     75020.0      1183.0         80.0      85.0        0.0
# 2020-05-31 20:02:05     53694.0      1121.0         90.0      92.0       18.0
# 2020-05-31 21:11:51     53701.0      1085.0         81.0      89.0       48.0
#
#                      torque  oil_psi  manifold_tmp  odometerinmeters
# msg_ts
# 2020-04-01 00:00:19     0.0    452.0          43.0       265633380.0
# 2020-04-01 00:01:06    16.0    388.0          32.0       284931580.0
# 2020-04-01 00:02:15     0.0    320.0          35.0        10278765.0
# 2020-04-01 00:02:21     0.0    380.0          39.0       265636940.0
# 2020-04-01 00:02:44    31.0    312.0          37.0       240438540.0
# ...                     ...      ...           ...               ...
# 2020-05-31 18:31:11    33.0    280.0          37.0       196080560.0
# 2020-05-31 18:41:46    71.0    264.0          33.0       186153820.0
# 2020-05-31 18:44:05    62.0    316.0          38.0       265525380.0
# 2020-05-31 20:02:05     8.0    320.0          62.0       186249040.0
# 2020-05-31 21:11:51    38.0    292.0          41.0       186262080.0
#
# [217876 rows x 9 columns]

# %%
X = df_pca.values              # getting all values as a matrix of dataframe 
sc = StandardScaler()          # creating a StandardScaler object
X_std = sc.fit_transform(X)    # standardizing the data

# %%
X
# Out:
# array([[8.3536000e+04, 1.4890000e+03, 8.4000000e+01, ..., 4.5200000e+02,
#         4.3000000e+01, 2.6563338e+08],
#        [1.9870000e+04, 1.3760000e+03, 8.1000000e+01, ..., 3.8800000e+02,
#         3.2000000e+01, 2.8493158e+08],
#        [2.8180000e+03, 1.1380000e+03, 8.1000000e+01, ..., 3.2000000e+02,
#         3.5000000e+01, 1.0278765e+07],
#        ...,
#        [7.5020000e+04, 1.1830000e+03, 8.0000000e+01, ..., 3.1600000e+02,
#         3.8000000e+01, 2.6552538e+08],
#        [5.3694000e+04, 1.1210000e+03, 9.0000000e+01, ..., 3.2000000e+02,
#         6.2000000e+01, 1.8624904e+08],
#        [5.3701000e+04, 1.0850000e+03, 8.1000000e+01, ..., 2.9200000e+02,
#         4.1000000e+01, 1.8626208e+08]])

# %%
X_std
# Out:
# array([[ 0.06598214,  1.52685989,  0.63889174, ...,  1.65244601,
#          0.60984574,  0.07199527],
#        [-1.31685231,  0.81368357, -0.11534233, ...,  0.5858086 ,
#         -0.57181676,  0.21482952],
#        [-1.68722414, -0.68840462, -0.11534233, ..., -0.54749366,
#         -0.24954517, -1.81799376],
#        ...,
#        [-0.11898657, -0.40439635, -0.36675368, ..., -0.6141585 ,
#          0.07272642,  0.07119591],
#        [-0.58219028, -0.79569663,  2.14735986, ..., -0.54749366,
#          2.65089917, -0.51556228],
#        [-0.58203824, -1.02290325, -0.11534233, ..., -1.01414753,
#          0.39499802, -0.51546577]])

# %%
pca = PCA()
X_pca = pca.fit(X_std)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
pca = PCA(n_components = 0.95)   # takes the variables required to explain 95 percent variance
X_pca = pca.fit_transform(X_std) # this will fit and reduce dimensions
print(pca.n_components_)
# Out:
# 6

# %%
pd.DataFrame(pca.components_, columns = df_pca.columns)
# Out:
#    fuel_total  engine_rpm  coolant_tmp  oil_tmpl  throt_pos    torque  \
# 0   -0.237330   -0.040614    -0.532620 -0.523863  -0.114933 -0.256983
# 1    0.641881    0.164944    -0.163805 -0.191565   0.020476 -0.048122
# 2   -0.159740    0.629275     0.063388  0.014905   0.463284  0.170227
# 3    0.031385   -0.346934    -0.194748 -0.273101   0.512909  0.679228
# 4   -0.057009   -0.071524    -0.231617 -0.202158  -0.506556  0.353444
# 5    0.025613    0.422598     0.158811 -0.006654  -0.492488  0.531018
#
#     oil_psi  manifold_tmp  odometerinmeters
# 0  0.305444     -0.397890         -0.230318
# 1  0.310418     -0.029603          0.630303
# 2  0.496530      0.190530         -0.218638
# 3 -0.171075     -0.104241          0.039766
# 4  0.169428      0.695824         -0.052181
# 5 -0.083513     -0.513246         -0.023859

# %%
n_pcs= pca.n_components_ # get number of component

# get the index of the most important feature on EACH component
most_important_variables = [np.abs(pca.components_[i]).argmax() for i in range(n_pcs)]

initial_variable_names = df_pca.columns

# get the most important feature names
most_important_variables = [initial_variable_names[most_important_variables[i]] for i in range(n_pcs)]

# %%
most_important_variables
# Out:
# ['coolant_tmp', 'fuel_total', 'engine_rpm', 'torque', 'manifold_tmp', 'torque']

# %% [markdown]
# # K means Clustering

# %% [markdown]
# https://andrewm4894.com/2020/09/03/time-series-clustering-with-tslearn/

# %%
df_xirgo
# Out:
#                       vin              msg_ts  fuel_total  engine_rpm  \
# 158551  3HSDZTZR5LN134290 2020-04-01 00:00:19     83536.0      1489.0
# 37732   3HSDWTZR5LN844783 2020-04-01 00:01:06     19870.0      1376.0
# 133253  3HSDZTZR3LN054647 2020-04-01 00:02:15      2818.0      1138.0
# 158552  3HSDZTZR5LN134290 2020-04-01 00:02:21     83536.0      1462.0
# 115243  3HSDZTZR1LN125327 2020-04-01 00:02:44     82402.0      1160.0
# ...                   ...                 ...         ...         ...
# 70545   3HSDWTZR9LN810071 2020-05-31 18:31:11     61931.0      1001.0
# 101146  3HSDZTZR0LN384388 2020-05-31 18:41:46     53670.0      1008.0
# 120195  3HSDZTZR1LN290908 2020-05-31 18:44:05     75020.0      1183.0
# 101147  3HSDZTZR0LN384388 2020-05-31 20:02:05     53694.0      1121.0
# 101148  3HSDZTZR0LN384388 2020-05-31 21:11:51     53701.0      1085.0
#
#         coolant_tmp  oil_tmpl  throt_pos  torque  oil_psi  manifold_tmp  \
# 158551         84.0      94.0        0.0     0.0    452.0          43.0
# 37732          81.0      83.0      100.0    16.0    388.0          32.0
# 133253         81.0      91.0        0.0     0.0    320.0          35.0
# 158552         82.0      91.0        0.0     0.0    380.0          39.0
# 115243         82.0      86.0        0.0    31.0    312.0          37.0
# ...             ...       ...        ...     ...      ...           ...
# 70545          82.0      86.0       37.0    33.0    280.0          37.0
# 101146         82.0      87.0        0.0    71.0    264.0          33.0
# 120195         80.0      85.0        0.0    62.0    316.0          38.0
# 101147         90.0      92.0       18.0     8.0    320.0          62.0
# 101148         81.0      89.0       48.0    38.0    292.0          41.0
#
#         odometerinmeters
# 158551       265633380.0
# 37732        284931580.0
# 133253        10278765.0
# 158552       265636940.0
# 115243       240438540.0
# ...                  ...
# 70545        196080560.0
# 101146       186153820.0
# 120195       265525380.0
# 101147       186249040.0
# 101148       186262080.0
#
# [217876 rows x 11 columns]

# %%
# df_xirgo['vin'].value_counts()

# %%
# !pip install tslearn
# Out:
# Collecting tslearn
#   Downloading https://files.pythonhosted.org/packages/95/98/9a67e2869a8b1416eb6e6fd5e69c56f86869980403b18f30bdb5783ade9d/tslearn-0.5.0.5-cp37-cp37m-manylinux2010_x86_64.whl (790kB)
#      |████████████████████████████████| 798kB 6.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.22.2.post1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.29.22)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.4.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.51.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->tslearn) (56.0.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->tslearn) (0.34.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.5.0.5

# %%
# Function for Clustering the columns for each VIN

def df_clustering(df = df_xirgo, 
                  columns_list = ['msg_ts','coolant_tmp', 'fuel_total', 'engine_rpm', 'oil_tmpl','oil_psi','torque', 'throt_pos', 'manifold_tmp'],
                  time_col = 'msg_ts', 
                  start_date = "2020-04-01", 
                  end_date = "2020-05-30",
                  n_clusters = 5):
  
  from tslearn.clustering import TimeSeriesKMeans
  from tslearn.preprocessing import TimeSeriesScalerMeanVariance
  
  df_out = pd.DataFrame({"vin": [], "variable" : [], "cluster": []})
  
  counter2 = 0

  for vin in df['vin'].unique():

    df_vin = df[df['vin'] == vin]                        #dataframe for single vin
    df_vin.drop(['vin'], axis = 1, inplace = True)

    df_vin_imp = pd.DataFrame(df_vin, columns = columns_list)   #dataframe with important columns

    df_vin_imp.set_index(pd.to_datetime(df_vin[time_col], unit='s'), drop = True, inplace = True)
    df_vin_imp.sort_index(ascending= True, inplace = True)
    df_vin_imp.drop(columns = [time_col],axis=1, inplace = True)

    after_start_date = df_vin_imp.index >= start_date
    before_end_date = df_vin_imp.index  < end_date
    between_two_dates = after_start_date & before_end_date         #the start and end date

    df_vin_imp_dates = df_vin_imp.loc[between_two_dates]           #dataframe for the selected period of dates

    if df_vin_imp_dates.shape[0] < 100:                           #if datapoints less than 100, increase counter by 1
      # print("{} has only {} datapoints in this time period".format(vin,df_vin_imp_dates.shape[0]))
      counter2 += 1

    df_vin_imp_dates = (df_vin_imp_dates-df_vin_imp_dates.min())/(df_vin_imp_dates.max()-df_vin_imp_dates.min())   #Min Max scaling

    X = df_vin_imp_dates.transpose().values
    
    counter = 1

    while True:
      try: 
        X = TimeSeriesScalerMeanVariance().fit_transform(X)       
        break
      except:
        counter = 0
        break

    if counter == 1:
      while True:
        try:
          df_kmeans = pd.DataFrame(X.reshape(df_vin_imp_dates.shape), columns=df_vin_imp_dates.columns, index=df_vin_imp_dates.index)
          break
        
        except:
          counter = 0
          break
      
    if counter == 1:  
      try:
        model = TimeSeriesKMeans(n_clusters=n_clusters, metric="dtw", max_iter=100, n_init=2).fit(X)

        df_cluster = pd.DataFrame(list(zip(df_kmeans.columns, model.labels_)), columns=['variable', 'cluster'])

        cluster_metrics_dict = df_cluster.groupby(['cluster'])['variable'].apply(lambda x: [x for x in x]).to_dict() #groupby and create dictionary 
        
        cluster_len_dict = df_cluster['cluster'].value_counts().to_dict()
         #if only one value in dictionary, ie key alone means no cluster assigned, drop value
        clusters_dropped = [cluster for cluster in cluster_len_dict if cluster_len_dict[cluster]==1] 
        clusters_final = [cluster for cluster in cluster_len_dict if cluster_len_dict[cluster]>1]
        clusters_final.sort()

        df_cluster['vin'] = vin

        df_out = df_out.append(df_cluster, ignore_index= True)

      except:
        None                                                                                                  

    else:
      None
      # print("{} VIN have no recorded values from {} to {}".format(vin,start_date, end_date))
    

  print("Total No. of VINS present : {}".format(df_out['vin'].nunique()))
  print("No. of VINS with datapoints less than 100 : {} ".format(counter2))
  print()

  dups = df_out[df_out.duplicated(['vin','cluster'], keep = False)].sort_values(['vin', 'cluster'])  #only selecting clusterswhich are duplicated for a vin

  return df_out , dups

# %%
# Function for giving number of Vins with selected variables in same cluster

def num_vins(var1 , var2, df):
  df_final = pd.DataFrame({"vin": [], "variable" : [], "cluster": []})

  for vin in df['vin'].unique():
    df_final = df_final.append(df[(df['vin'] == vin) & (df['variable'].isin ([var1, var2]))])  #condition, vin, var1 & var2 as var1 & var2 passed


  df_final = df_final[df_final.duplicated(['vin','cluster'], keep = False)].sort_values(['vin', 'cluster'])  #keeping only duplicated

  return df_final['vin'].nunique()


#Looping the above function for all variables

def vins_with_var_in_same_cluster(df, time_period):
  df_vins_number = pd.DataFrame({"Variable1": [], "Variable2" : [], time_period: []})
  for i in range(len(df['variable'].unique())):
      for j in range(len(df['variable'].unique())):
          out2 = num_vins(df['variable'].unique()[i],df['variable'].unique()[j], df)
          df_vins_number = df_vins_number.append(pd.DataFrame({"Variable1": [df['variable'].unique()[i]], 
                                                               "Variable2" : [df['variable'].unique()[j]], 
                                                               time_period: [out2]}), ignore_index= True )
  
  df_vins_number = df_vins_number[df_vins_number['Variable1'] != df_vins_number['Variable2']]  #dropping if var1 = var2

  df_vins_number.sort_values(['Variable1', 'Variable2'], ascending = [True, True], inplace = True)
  
  df_vins_number.reset_index(inplace = True, drop = True)

  return df_vins_number

# %%
time_period = 'Week1'
start_date = "2020-04-01"
end_date = "2020-04-08"

df_out, dups = df_clustering(start_date = start_date , end_date = end_date)

df_vins_number = vins_with_var_in_same_cluster(dups,time_period)

df_weekly = df_vins_number
# Out:
# Total No. of VINS present : 82
# No. of VINS with datapoints less than 100 : 19

# %%
time_period = 'Week2'
start_date = "2020-04-08"
end_date = "2020-04-15"

df_out, dups = df_clustering(start_date = start_date , end_date = end_date)

df_vins_number = vins_with_var_in_same_cluster(dups,time_period)

df_weekly[time_period] = list(df_vins_number[time_period])
# Out:
# Total No. of VINS present : 85
# No. of VINS with datapoints less than 100 : 21

# %%
time_period = 'Week3'
start_date = "2020-04-15"
end_date = "2020-04-22"

df_out, dups = df_clustering(start_date = start_date , end_date = end_date)

df_vins_number = vins_with_var_in_same_cluster(dups,time_period)

df_weekly[time_period] = list(df_vins_number[time_period])
# Out:
# Total No. of VINS present : 83
# No. of VINS with datapoints less than 100 : 19

# %%
time_period = 'Week4'
start_date = "2020-04-22"
end_date = "2020-04-29"

df_out, dups = df_clustering(start_date = start_date , end_date = end_date)

df_vins_number = vins_with_var_in_same_cluster(dups,time_period)

df_weekly[time_period] = list(df_vins_number[time_period])
# Out:
# Total No. of VINS present : 87
# No. of VINS with datapoints less than 100 : 26

# %%
time_period = 'Week5'
start_date = "2020-04-29"
end_date = "2020-05-06"

df_out, dups = df_clustering(start_date = start_date , end_date = end_date)

df_vins_number = vins_with_var_in_same_cluster(dups,time_period)

df_weekly[time_period] = list(df_vins_number[time_period])
# Out:
# Total No. of VINS present : 81
# No. of VINS with datapoints less than 100 : 23

# %%
time_period = 'Week6'
start_date = "2020-05-06"
end_date = "2020-05-13"

df_out, dups = df_clustering(start_date = start_date , end_date = end_date)

df_vins_number = vins_with_var_in_same_cluster(dups,time_period)

df_weekly[time_period] = list(df_vins_number[time_period])
# Out:
# Total No. of VINS present : 86
# No. of VINS with datapoints less than 100 : 35

# %%
time_period = 'Week7'
start_date = "2020-05-13"
end_date = "2020-05-20"

df_out, dups = df_clustering(start_date = start_date , end_date = end_date)

df_vins_number = vins_with_var_in_same_cluster(dups,time_period)

df_weekly[time_period] = list(df_vins_number[time_period])
# Out:
# Total No. of VINS present : 92
# No. of VINS with datapoints less than 100 : 71

# %%
time_period = 'Week8'
start_date = "2020-05-20"
end_date = "2020-05-27"

df_out, dups = df_clustering(start_date = start_date , end_date = end_date)

df_vins_number = vins_with_var_in_same_cluster(dups,time_period)

df_weekly[time_period] = list(df_vins_number[time_period])

# %% [markdown]
# **No. of VINS with variable1 and variable2 in same cluster**

# %%
df_weekly

# %% [markdown]
# **In same clusters (>10) - showing similar characteristics [all time]**
#
# 1 - Coolant Temp - Manifold Temp, Vehicle speed
#
# 2 - enginerpm - throt pos, vehicle speed
#
# 3 - fuel total
#
# 4 - manifold temp - coolant temp, torque, vehicle speed
#
# 5 - throt pos - engine rpm, torque
#
# 6 - torque - manifold temp, throt pos, throt pos
#
# 7 - vehicle speed - coolant temp, engine rpm, manifold temp, throt pos
